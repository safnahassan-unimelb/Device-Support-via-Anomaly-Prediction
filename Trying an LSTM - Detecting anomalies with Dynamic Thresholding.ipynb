# %%
pip install --upgrade pyod
# Out:
# Requirement already satisfied: pyod in c:\python310\lib\site-packages (1.1.3)
# Requirement already satisfied: matplotlib in c:\python310\lib\site-packages (from pyod) (3.5.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\python310\lib\site-packages (from pyod) (1.1.1)
# Requirement already satisfied: joblib in c:\python310\lib\site-packages (from pyod) (1.1.0)
# Requirement already satisfied: numba>=0.51 in c:\python310\lib\site-packages (from pyod) (0.58.1)
# Requirement already satisfied: numpy>=1.19 in c:\python310\lib\site-packages (from pyod) (1.23.1)
# Requirement already satisfied: scipy>=1.5.1 in c:\python310\lib\site-packages (from pyod) (1.9.0)
# Requirement already satisfied: six in c:\python310\lib\site-packages (from pyod) (1.16.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\python310\lib\site-packages (from numba>=0.51->pyod) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn>=0.22.0->pyod) (3.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib->pyod) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib->pyod) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib->pyod) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib->pyod) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib->pyod) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib->pyod) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib->pyod) (2.8.2)
#
# [notice] A new release of pip available: 22.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install combo
# Out:
# Requirement already satisfied: combo in c:\python310\lib\site-packages (0.1.3)
# Requirement already satisfied: numba>=0.35 in c:\python310\lib\site-packages (from combo) (0.58.1)
# Requirement already satisfied: pyod in c:\python310\lib\site-packages (from combo) (1.1.3)
# Requirement already satisfied: matplotlib in c:\python310\lib\site-packages (from combo) (3.5.2)
# Requirement already satisfied: numpy>=1.13 in c:\python310\lib\site-packages (from combo) (1.23.1)
# Requirement already satisfied: joblib in c:\python310\lib\site-packages (from combo) (1.1.0)
# Requirement already satisfied: scipy in c:\python310\lib\site-packages (from combo) (1.9.0)
# Requirement already satisfied: scikit-learn>=0.20 in c:\python310\lib\site-packages (from combo) (1.1.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\python310\lib\site-packages (from numba>=0.35->combo) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn>=0.20->combo) (3.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib->combo) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib->combo) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib->combo) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib->combo) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib->combo) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib->combo) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib->combo) (1.4.4)
# Requirement already satisfied: six in c:\python310\lib\site-packages (from pyod->combo) (1.16.0)
#
# [notice] A new release of pip available: 22.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from pandas import json_normalize
import json
from datetime import datetime
import pytz
import matplotlib.pyplot as plt
import ruptures as rpt
from collections import Counter

# %%
columns = ['sensors.battery.temp',
       'sensors.battery.percent', 'sensors.battery.solarmv',
       'sensors.battery.current', 'sensors.battery.voltage',
       'sensors.battery.solarma', 'sensors.battery.charging',
        'solar_power', 'battery_power','power_difference']

# %%
# Reading back and setting the MultiIndex
labelled_data = pd.read_feather('MTDataBatch1\Labelled Data\Labelled Batch 1 - Updated.feather')
#                 2021-04-21 03:27:29+10:00          0.000000            False
#                 2021-04-21 03:28:29+10:00          0.000000            False
#                 2021-04-21 03:21:30+10:00          0.000000            False
# ...                                                     ...              ...
# 015262001276442 2021-11-22 13:01:23+11:00          0.286953            False
#                 2021-11-22 13:04:17+11:00          0.288705            False
#                 2021-11-23 13:05:02+11:00          0.260746            False
#                 2021-11-24 13:05:36+11:00          0.225512            False
#                 2021-11-24 13:05:02+11:00          0.212981            False
#
#                                               predictive_parameter
# DeviceId        time
# 015262001277846 2021-04-21 03:18:26+10:00                     None
#                 2021-04-21 03:17:52+10:00                     None
#                 2021-04-21 03:27:29+10:00                     None
#                 2021-04-21 03:28:29+10:00                     None
#                 2021-04-21 03:21:30+10:00                     None
# ...                                                            ...
# 015262001276442 2021-11-22 13:01:23+11:00  sensors.battery.solarma
#                 2021-11-22 13:04:17+11:00  sensors.battery.solarma
#                 2021-11-23 13:05:02+11:00  sensors.battery.solarma
#                 2021-11-24 13:05:36+11:00  sensors.battery.solarma
#                 2021-11-24 13:05:02+11:00  sensors.battery.solarma
#
# [1684083 rows x 31 columns]

# %%
labelled_data = labelled_data.sort_index(level=['DeviceId', 'time'])

# %%
numberOfDevices = len(labelled_data.groupby(level=0))
numberOfDevices
# Out:
# 35

# %%
column_list = list(labelled_data.columns)
# for column in column_list:
#     print(column)
#     print(labelled_data[column].isnull().values.any())
#     print("-------------------")

# %%
len(labelled_data.columns)
# Out:
# 31

# %%
train_size = int(len(labelled_data) * 0.80)
test_size = len(labelled_data) - train_size

# %%
# Training data : take all rows, and only device feature columns (From "sensors.battery.extpower" to "power_difference")
train_data = labelled_data.iloc[0:train_size,6:29]
test_data = labelled_data.iloc[train_size:len(labelled_data),6:29]
# Drop columns that have string values, or even NaN values 
# Manual Inspection proved them as non important for malfunction detectio.
train_data = train_data.drop('location.source', axis=1)
train_data = train_data.drop('location.numSats', axis=1)
train_data = train_data.drop('sensors.accelerometer.y', axis=1)
train_data = train_data.drop('sensors.accelerometer.x', axis=1)
train_data = train_data.drop('sensors.accelerometer.z', axis=1)
test_data = test_data.drop('location.source', axis=1)
test_data = test_data.drop('location.numSats', axis=1)
test_data = test_data.drop('sensors.accelerometer.y', axis=1)
test_data = test_data.drop('sensors.accelerometer.x', axis=1)
test_data = test_data.drop('sensors.accelerometer.z', axis=1)
# Labels is the array of values in "isDeviceWorking" -  convert to array of inetgers (0 or 1 values)
labels = labelled_data.iloc[:,29].values

# %%
# train_data_label = pd.DataFrame(labelled_data.iloc[0:train_size,29].values.astype(int), columns=['isDeviceWorking'])
# test_data_label = pd.DataFrame(labelled_data.iloc[train_size:len(labelled_data),29].values.astype(int), columns=['isDeviceWorking'])
train_data.head()
# Out:
#                                            sensors.battery.extpower  \
# DeviceId        time
# 015262001090339 2021-06-11 12:27:45+10:00                      True
#                 2021-06-11 12:34:17+10:00                      True
#                 2021-06-11 16:34:25+10:00                      True
#                 2021-06-11 20:34:39+10:00                     False
#                 2021-06-12 00:35:02+10:00                     False
#
# DeviceId        time
# 015262001090339 2021-06-11 12:27:45+10:00         -37.916618               0
#                 2021-06-11 12:34:17+10:00         -37.916505               0
#                 2021-06-11 16:34:25+10:00         -37.916505               0
#                 2021-06-11 20:34:39+10:00         -37.916505               0
#                 2021-06-12 00:35:02+10:00         -37.916505               0
#
#                                            location.accuracy  solar_power  \
# DeviceId        time
# 015262001090339 2021-06-11 12:27:45+10:00             17.469     0.001950
#                 2021-06-11 12:34:17+10:00              1.839     0.000000
#                 2021-06-11 16:34:25+10:00              1.839     0.003528
#                 2021-06-11 20:34:39+10:00              1.839     0.000000
#                 2021-06-12 00:35:02+10:00              1.839     0.000000
#
#                                            battery_power  power_difference
# DeviceId        time
# 015262001090339 2021-06-11 12:27:45+10:00       2.961378         -2.959428
#                 2021-06-11 12:34:17+10:00       1.178067          0.000000
#                 2021-06-11 16:34:25+10:00       1.174122         -1.170594
#                 2021-06-11 20:34:39+10:00      -0.152360          0.000000
#                 2021-06-12 00:35:02+10:00      -0.121856          0.000000

# %%
len(train_data.columns)
# Out:
# 18

# %%
# # Timestamps of devices that are working
# train_data_label.loc[train_data_label['isDeviceWorking'] == 1]

# %%
deviceWorkingLabels = labelled_data[['isDeviceWorking']].copy()
deviceWorkingLabels['isDeviceWorking'] = deviceWorkingLabels['isDeviceWorking'].astype(int)
deviceWorkingLabels
# Out:
#                                            isDeviceWorking
# DeviceId        time
# 015262001090339 2021-06-11 12:27:45+10:00                1
#                 2021-06-11 12:34:17+10:00                1
#                 2021-06-11 16:34:25+10:00                1
#                 2021-06-11 20:34:39+10:00                1
#                 2021-06-12 00:35:02+10:00                1
# ...                                                    ...
# 015262001281806 2021-11-09 09:42:02+11:00                0
#                 2021-11-10 09:42:09+11:00                0
#                 2021-11-10 09:45:07+11:00                0
#                 2021-11-11 09:45:49+11:00                0
#                 2021-11-11 09:46:42+11:00                0
#
# [1684083 rows x 1 columns]

# %%
train_data_label = deviceWorkingLabels.iloc[0:train_size,:]
test_data_label = deviceWorkingLabels.iloc[train_size:len(deviceWorkingLabels),:]

# %%
train_data_label
# Out:
#                                            isDeviceWorking
# DeviceId        time
# 015262001090339 2021-06-11 12:27:45+10:00                1
#                 2021-06-11 12:34:17+10:00                1
#                 2021-06-11 16:34:25+10:00                1
#                 2021-06-11 20:34:39+10:00                1
#                 2021-06-12 00:35:02+10:00                1
# ...                                                    ...
# 015262001278133 2021-06-15 01:05:16+10:00                1
#                 2021-06-15 01:06:16+10:00                1
#                 2021-06-15 01:07:20+10:00                1
#                 2021-06-15 01:08:37+10:00                1
#                 2021-06-15 01:09:39+10:00                1
#
# [1347266 rows x 1 columns]

# %%
# Scale column values (without normalizing the indexes)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1,1))

# Group by level 0, which is the first index corresponding to 'DeviceId'
# After applying the scaling function (which output a Numpy array), convert it to a dataframe

normalized_train_data = train_data.groupby(level=0).apply(lambda x : pd.DataFrame(scaler.fit_transform(x), columns=x.columns, index=x.index).round(5))
    
normalized_test_data = test_data.groupby(level=0).apply(lambda x : pd.DataFrame(scaler.fit_transform(x), columns=x.columns, index=x.index).round(5))

# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# scaler.fit(train_data)

# normalized_train_data = pd.DataFrame(scaler.transform(train_data))
# normalized_test_data = pd.DataFrame(scaler.transform(test_data))
normalized_test_data
# Out:
#                                            sensors.battery.extpower  \
# DeviceId        time
# 015262001278133 2021-06-15 01:10:39+10:00                      -1.0
#                 2021-06-15 01:11:37+10:00                      -1.0
#                 2021-06-15 01:12:40+10:00                      -1.0
#                 2021-06-15 01:13:40+10:00                      -1.0
#                 2021-06-15 01:14:42+10:00                      -1.0
# ...                                                             ...
# 015262001281806 2021-11-09 09:42:02+11:00                      -1.0
#                 2021-11-10 09:42:09+11:00                      -1.0
#                 2021-11-10 09:45:07+11:00                      -1.0
#                 2021-11-11 09:45:49+11:00                      -1.0
#                 2021-11-11 09:46:42+11:00                      -1.0
#
#                                            sensors.battery.temp  \
# DeviceId        time
# 015262001278133 2021-06-15 01:10:39+10:00              -0.46263
#                 2021-06-15 01:11:37+10:00              -0.46263
#                 2021-06-15 01:12:40+10:00              -0.46667
#                 2021-06-15 01:13:40+10:00              -0.46667
#                 2021-06-15 01:14:42+10:00              -0.46667
# ...                                                         ...
# 015262001281806 2021-11-09 09:42:02+11:00              -0.16606
#                 2021-11-10 09:42:09+11:00              -0.16968
#                 2021-11-10 09:45:07+11:00              -0.14079
#                 2021-11-11 09:45:49+11:00              -0.04693
#                 2021-11-11 09:46:42+11:00              -0.04693
#
#                                            sensors.battery.percent  \
# DeviceId        time
# 015262001278133 2021-06-15 01:10:39+10:00                  1.00000
#                 2021-06-15 01:11:37+10:00                  1.00000
#                 2021-06-15 01:12:40+10:00                  1.00000
#                 2021-06-15 01:13:40+10:00                  1.00000
#                 2021-06-15 01:14:42+10:00                  1.00000
# ...                                                            ...
# 015262001281806 2021-11-09 09:42:02+11:00                 -0.97534
#                 2021-11-10 09:42:09+11:00                 -0.98356
#                 2021-11-10 09:45:07+11:00                 -0.99178
#                 2021-11-11 09:45:49+11:00                 -1.00000
#                 2021-11-11 09:46:42+11:00                 -0.99726
#
#                                            sensors.battery.solarmv  \
# DeviceId        time
# 015262001278133 2021-06-15 01:10:39+10:00                 -1.00000
#                 2021-06-15 01:11:37+10:00                 -0.97759
#                 2021-06-15 01:12:40+10:00                 -1.00000
#                 2021-06-15 01:13:40+10:00                 -1.00000
#                 2021-06-15 01:14:42+10:00                 -1.00000
# ...                                                            ...
# 015262001281806 2021-11-09 09:42:02+11:00                 -0.38856
#                 2021-11-10 09:42:09+11:00                 -0.22449
#                 2021-11-10 09:45:07+11:00                 -0.24610
#                 2021-11-11 09:45:49+11:00                 -0.13886
#                 2021-11-11 09:46:42+11:00                 -0.13806
#
#                                            sensors.battery.current  \
# DeviceId        time
# 015262001278133 2021-06-15 01:10:39+10:00                 -0.32571
#                 2021-06-15 01:11:37+10:00                 -0.22286
#                 2021-06-15 01:12:40+10:00                 -0.35429
#                 2021-06-15 01:13:40+10:00                 -0.31429
#                 2021-05-30 07:30:27+10:00       -0.01874          -0.42185
#                 2021-05-31 07:31:02+10:00       -0.60693          -0.07983
#                 2021-05-31 07:31:46+10:00       -0.33956          -0.22917
#                 2021-06-01 07:32:25+10:00       -0.36597          -0.24622
#                 2021-06-02 07:32:31+10:00       -0.20400          -0.33437
#
# [5142 rows x 18 columns]

# %%
# LSTM is a type of RNN - we need sequences that act as an input to the LSTM. Chunks of timestamps are used as sequences

# Create sequences for each device. Take timestamps for each deviceId and form sequences taking 10 time steps at a time.
def create_dataset(X, y, time_steps = 1):
    Xs, ys = [],[]
#     Get list of devieIDs in datatset
    deviceIDs = set(X.index.get_level_values(0).tolist())
    
    for device in deviceIDs:
        xForDeviceId = X[X.index.get_level_values('DeviceId') == device]
        yForDeviceId = y[y.index.get_level_values('DeviceId') == device]
        for i in range(len(xForDeviceId) - time_steps):
    #         Take the value of current time step (x) and do a bit of indexing. 
            v = xForDeviceId.iloc[i:(i + time_steps)].values
            Xs.append(v)
            ys.append(yForDeviceId.iloc[i + time_steps].values)
            
    return np.array(Xs), np.array(ys)

# def create_dataset(X, y, time_steps = 1):
#     Xs, ys = [],[]
#     for i in range(len(X) - time_steps):
# #         Take the value of current time step (x) and do a bit of indexing. 
#         v = X.iloc[i:(i + time_steps)].values
#         Xs.append(v)
#         ys.append(y.iloc[i + time_steps])
#     return np.array(Xs), np.array(ys)

# %%
# Create sequences for each device. Take timestamps for each deviceId and form sequences taking 10 time steps at a time.
def create_dataset_new(X, y, time_steps = 1):
    Xs, ys = [],[]
    index_of_sequences = []
#     Get list of devieIDs in datatset
    deviceIDs = set(X.index.get_level_values(0).tolist())
    
    for device in deviceIDs:
        xForDeviceId = X[X.index.get_level_values('DeviceId') == device]
        yForDeviceId = y[y.index.get_level_values('DeviceId') == device]
        for i in range(len(xForDeviceId) - time_steps):
    #         Take the value of current time step (x) and do a bit of indexing. 
            v = xForDeviceId.iloc[i:(i + time_steps)].values
            Xs.append(v)
            ys.append(yForDeviceId.iloc[i + time_steps])
            index_of_sequences.append(yForDeviceId.iloc[i:i+1].index.tolist()[0])
#             print(index_of_sequences)
            
    return np.array(Xs), np.array(ys), index_of_sequences

# %%
# Convert train dataset into sequences
# Start with 10 time steps as history.

TIME_STEPS = 5

X_train_new, y_train_new, train_index_list= create_dataset_new(normalized_train_data, train_data_label.isDeviceWorking, TIME_STEPS)
len(train_index_list)
# Out:
# 1347121

# %%
X_test_new, y_test_new, test_index_list = create_dataset_new(normalized_test_data,test_data_label.isDeviceWorking,TIME_STEPS)

# %%
test_data_label.isDeviceWorking.iloc[0:1].index.tolist()[0]
# Out:
# ('015262001278133',
#  Timestamp('2021-06-15 01:10:39+1000', tz='Australia/Sydney'))

# %%
test_index_list
# Out:
# [('015262001278422',
#   Timestamp('2021-04-21 03:02:07+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:03:06+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:04:08+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:05:09+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:06:12+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:07:10+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:08:13+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:09:11+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:10:10+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:11:11+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:12:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:12:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:12:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:13:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:13:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:13:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:14:32+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03:14:32+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-21 03
1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:09:10+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:10:10+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:11:11+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:12:10+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:13:35+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:14:34+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:15:35+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:16:37+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:17:38+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:18:38+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:19:40+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:20:40+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:21:40+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:22:42+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:23:57+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:24:54+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:25:57+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:26:58+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:27:56+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:28:58+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:29:56+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:31:02+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:32:02+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:33:00+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:34:25+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:35:26+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:36:28+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:37:27+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:38:30+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:39:29+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:40:30+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:41:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:42:30+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:43:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:44:51+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:45:50+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:46:56+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:47:53+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:48:51+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:49:51+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:50:50+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:51:55+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:53:01+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:53:53+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:55:13+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:56:15+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:57:13+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:58:12+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 01:59:13+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:00:12+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:01:13+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:02:14+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:03:16+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:04:18+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:05:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:06:32+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:07:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:08:36+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:09:31+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:10:29+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:11:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:12:32+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:13:36+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:14:37+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:15:33+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:16:36+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:17:37+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:18:36+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:19:38+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:20:37+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:21:35+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:22:36+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:22:55+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:53:25+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:53:59+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:55:04+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:56:03+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:57:02+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:58:02+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 02:58:21+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 06:58:27+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 09:40:31+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 09:41:05+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 09:42:10+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 09:43:08+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 09:44:07+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 09:45:07+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 09:45:27+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:11:19+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:11:53+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:12:59+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:14:00+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:14:59+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:16:00+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:17:01+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:18:02+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:19:04+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:20:04+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:21:05+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:22:06+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:23:06+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:24:05+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:25:07+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:26:07+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:27:09+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:28:10+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:29:10+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:30:11+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:31:12+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:32:14+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:33:18+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:33:18+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:33:18+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:34:17+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:34:17+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:34:17+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:35:15+1000', tz='Australia/Sydney')),
#  ('015262001278422',
#   Timestamp('2021-04-22 10:35:15+1000', tz='Australia/Sydney')),
#  ...]

# %%
# Convert train dataset into sequences
# Start with 5 time steps as history.

# TIME_STEPS = 5

X_train, y_train = create_dataset(normalized_train_data, train_data_label, TIME_STEPS)
X_test, y_test = create_dataset(normalized_test_data,test_data_label,TIME_STEPS)

# %%
len(y_test)
# Out:
# 336782

# %%
# The shape of the created sequence dataset: 
# it's a 3-D tensor which contains the timeseries, time step (history), and number of features
X_train.shape
# Out:
# (1347121, 5, 18)

# %%
y_train.shape
# Out:
# (1347121, 1)

# %%
# The sequences form the input to LSTM Autoencoder
# Idea behind this is to train a model based on our data, measure the error post training. 
# If the error is above a threshold, the model cannot reconstruct the data, indicative of an anomaly (predictive)

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
from keras import models
from keras import layers
from keras.datasets import imdb
from time import time
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, RepeatVector, TimeDistributed

# %%
model = Sequential()
# Add an LSTM Layer with 64 units
model.add(LSTM(
    units=64, 
    input_shape=(X_train.shape[1], X_train.shape[2])
))

# Add a dropout layer for regularization
model.add(Dropout(rate = 0.2))

# add a repeat layer
# This is important because we need to return the sequence for the next LSTM layer to work with.
model.add(RepeatVector(n=X_train.shape[1]))

# Add another LSTM Layer
model.add(LSTM(
    units=64, 
    return_sequences=True
))
model.add(Dropout(rate = 0.2))

# Output time distributed, fully connected layer 
# return same amount of data that was given as input, 
# that is reconstructed after learning the most important features of our data

model.add(TimeDistributed(Dense(
#     Number of features that we have is the number of dimensions of our predictions column, which is y_train.shape[1]
#     units = X_train.shape[2]   
    units = y_train.shape[1]
)))

model.compile(loss='mae', optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                21248
#
#  dropout (Dropout)           (None, 64)                0
#
#  repeat_vector (RepeatVector  (None, 5, 64)            0
#  )
#
#  lstm_1 (LSTM)               (None, 5, 64)             33024
#
#  dropout_1 (Dropout)         (None, 5, 64)             0
#
#  time_distributed (TimeDistr  (None, 5, 1)             65
#  ibuted)
#
# =================================================================
# Total params: 54,337
# Trainable params: 54,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
# Important: In time series data, do not shuffle the data because data is history dependent
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.1,
    shuffle = False
)
# Out:
# Epoch 1/10
# 37888/37888 [==============================] - 537s 14ms/step - loss: 0.0462 - val_loss: 0.4268
# Epoch 2/10
# 37888/37888 [==============================] - 525s 14ms/step - loss: 0.0458 - val_loss: 0.3959
# Epoch 3/10
# 37888/37888 [==============================] - 1082s 29ms/step - loss: 0.0457 - val_loss: 0.3966
# Epoch 4/10
# 37888/37888 [==============================] - 532s 14ms/step - loss: 0.0482 - val_loss: 0.3683
# Epoch 5/10
# 37888/37888 [==============================] - 532s 14ms/step - loss: 0.0524 - val_loss: 0.2088
# Epoch 6/10
# 37888/37888 [==============================] - 533s 14ms/step - loss: 0.0782 - val_loss: 0.1108
# Epoch 7/10
# 37888/37888 [==============================] - 533s 14ms/step - loss: 0.1086 - val_loss: 0.1086
# Epoch 8/10
# 37888/37888 [==============================] - 537s 14ms/step - loss: 0.1019 - val_loss: 0.0917
# Epoch 9/10
# 37888/37888 [==============================] - 6834s 180ms/step - loss: 0.1091 - val_loss: 0.0972
# Epoch 10/10
# 37888/37888 [==============================] - 219s 6ms/step - loss: 0.1065 - val_loss: 0.1040

# %%
# As you can see, validation loss decreases steadily in above output (indicates some hints of possible learning)

plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'test')
plt.legend();

# %%
# Take the predictions for the training data that we have
X_train_pred = model.predict(X_train)
# Out:
# 42098/42098 [==============================] - 80s 2ms/step

# %%
X_train_pred.shape
# Out:
# (1347121, 5, 1)

# %%
X_train_pred_reshaped = X_train_pred[:,0,:]

# %%
y_train
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
# take mae on training set and calculate error

import seaborn as sns
train_mae_loss = np.mean(np.abs(X_train_pred_reshaped - y_train.astype('float32')), axis =1)
sns.distplot(train_mae_loss, bins=50,kde=True)
# This gives us an idea of what to set as a threshold (which is a hyperparameter)
# Out:
# C:\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# Do the same for test set
X_test_pred = model.predict(X_test)
X_test_pred_reshaped = X_test_pred[:,0,:]
test_mae_loss = np.mean(np.abs(X_test_pred_reshaped - y_test.astype('float32')), axis =1)
# Out:
# 10525/10525 [==============================] - 21s 2ms/step

# %%
len(X_test_pred)
# Out:
# 336782

# %%
X_test_pred_reshaped.shape
# Out:
# (336782, 1)

# %%
sns.distplot(test_mae_loss, bins=50,kde=True)
# Out:
# C:\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
test_data_label
# Out:
#                                            isDeviceWorking
# DeviceId        time
# 015262001278133 2021-06-15 01:10:39+10:00                1
#                 2021-06-15 01:11:37+10:00                1
#                 2021-06-15 01:12:40+10:00                1
#                 2021-06-15 01:13:40+10:00                1
#                 2021-06-15 01:14:42+10:00                1
# ...                                                    ...
# 015262001281806 2021-11-09 09:42:02+11:00                0
#                 2021-11-10 09:42:09+11:00                0
#                 2021-11-10 09:45:07+11:00                0
#                 2021-11-11 09:45:49+11:00                0
#                 2021-11-11 09:46:42+11:00                0
#
# [336817 rows x 1 columns]

# %%
len(y_test_new)
# Out:
# 336782

# %%
# Dynamic thresholding: εij = μ(eij ) + zσ(eij )
# Find mean and SD of errors
# Find suitable z to calculate threshold. 

# Find mean with no axis, i.e.:  to compute the mean of the flattened array
mean = np.mean(np.abs(X_train_pred_reshaped - y_train.astype('float32')))
standard_deviation = np.std(np.abs(X_train_pred_reshaped - y_train.astype('float32')))

# Dynamic Threshold
# Here, the z value is dynamic
# Values for z depend on context, usually between two and ten to work well based on our experimental results.

# Dynamic Threshold with z = 1-.75
dynamic_threshold = (mean + (0.75*standard_deviation))

# %%
dynamic_threshold
# Out:
# 0.5043392926454544

# %%
# Perform thresholding
THRESHOLD = 0.75

test_score_df = pd.DataFrame(index=pd.MultiIndex.from_tuples(test_index_list, names=('DeviceId', 'time')))
# test_score_df = pd.DataFrame(index=test_data_label[TIME_STEPS:].index)
test_score_df['loss'] = test_mae_loss
test_score_df['threshold'] = dynamic_threshold
test_score_df['anomaly'] = test_score_df.loss > test_score_df.threshold
# test_score_df['isDeviceWorking'] = test_data_label.isDeviceWorking
test_score_df['isDeviceWorking'] = y_test_new

# %%
# test_score_df.loc[test_score_df['anomaly'] == False]
test_score_df
# Out:
#                                                loss  threshold  anomaly  \
# DeviceId        time
# 015262001278422 2021-04-21 03:02:07+10:00  0.001004   0.504339    False
#                 2021-04-21 03:03:06+10:00  0.001004   0.504339    False
#                 2021-04-21 03:04:08+10:00  0.001004   0.504339    False
#                 2021-04-21 03:05:09+10:00  0.001004   0.504339    False
#                 2021-04-21 03:06:12+10:00  0.001004   0.504339    False
# ...                                             ...        ...      ...
# 015262001278513 2021-09-10 06:37:53+10:00  0.066213   0.504339    False
#                 2021-09-10 06:42:53+10:00  0.069508   0.504339    False
#                 2021-09-10 06:46:07+10:00  0.066863   0.504339    False
#                 2021-09-10 22:46:54+10:00  0.066013   0.504339    False
#                 2021-09-10 22:47:57+10:00  0.065113   0.504339    False
#
#                                            isDeviceWorking
# DeviceId        time
# 015262001278422 2021-04-21 03:02:07+10:00                1
#                 2021-04-21 03:03:06+10:00                1
#                 2021-04-21 03:04:08+10:00                1
#                 2021-04-21 03:05:09+10:00                1
#                 2021-04-21 03:06:12+10:00                1
# ...                                                    ...
# 015262001278513 2021-09-10 06:37:53+10:00                0
#                 2021-09-10 06:42:53+10:00                0
#                 2021-09-10 06:46:07+10:00                0
#                 2021-09-10 22:46:54+10:00                0
#                 2021-09-10 22:47:57+10:00                0
#
# [336782 rows x 4 columns]

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(8)
plt.plot(test_score_df.index.get_level_values('time').values, test_score_df.loss, label = 'loss')
plt.plot(test_score_df.index.get_level_values('time').values,test_score_df.threshold, label = 'threshold')
plt.xticks(rotation=25)
plt.legend()

# %%
testdeviceIDs = set(test_score_df.index.get_level_values(0).tolist())
print(testdeviceIDs)
for device in testdeviceIDs:
    fig, ax = plt.subplots()
    test_preds = test_score_df[test_score_df.index.get_level_values('DeviceId') == device]
    loss = test_preds.loss
    threshold = test_preds.threshold
    trueValues = test_preds.isDeviceWorking

    ax.plot(test_preds.index.get_level_values('time').values, loss, linewidth=2, label = 'loss')
    ax.plot(test_preds.index.get_level_values('time').values, threshold, label='threshold',linestyle="--", linewidth=1)
    ax.plot(test_preds.index.get_level_values('time').values, trueValues, linewidth=2, label = 'is Device Working')

    # Set x-axis label
    ax.set_xlabel('Time')

    # Set y-axis label
    ax.set_ylabel('MAE Loss for '+device)

    # Set legend
    ax.legend()

    # Show plot
    plt.show()
# Out:
# {'015262001278422', '015262001278323', '015262001278372', '015262001278315', '015262001278133', '015262001281806', '015262001278513'}

# %%
anomalies = test_score_df[test_score_df.anomaly == True]
anomalies
# Out:
#                                                loss  threshold  anomaly  \
# DeviceId        time
# 015262001278323 2021-06-03 18:12:18+10:00  0.843337       0.75     True
#                 2021-06-03 18:13:18+10:00  0.936017       0.75     True
#                 2021-06-03 18:14:18+10:00  0.825020       0.75     True
#                 2021-06-03 18:16:10+10:00  0.892466       0.75     True
#                 2021-06-03 18:16:45+10:00  0.941899       0.75     True
# ...                                             ...        ...      ...
# 015262001278372 2021-06-04 15:38:45+10:00  0.804626       0.75     True
#                 2021-06-04 15:39:47+10:00  0.804547       0.75     True
#                 2021-06-04 15:40:57+10:00  0.804547       0.75     True
#                 2021-06-04 15:42:03+10:00  0.804713       0.75     True
#                 2021-06-04 15:43:16+10:00  0.804509       0.75     True
#
#                                            isDeviceWorking
# DeviceId        time
# 015262001278323 2021-06-03 18:12:18+10:00                1
#                 2021-06-03 18:13:18+10:00                1
#                 2021-06-03 18:14:18+10:00                1
#                 2021-06-03 18:16:10+10:00                1
#                 2021-06-03 18:16:45+10:00                1
# ...                                                    ...
# 015262001278372 2021-06-04 15:38:45+10:00                1
#                 2021-06-04 15:39:47+10:00                1
#                 2021-06-04 15:40:57+10:00                1
#                 2021-06-04 15:42:03+10:00                1
#                 2021-06-04 15:43:16+10:00                1
#
# [111466 rows x 4 columns]

# %%
len(test_score_df)
# Out:
# 336782
